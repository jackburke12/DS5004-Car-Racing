# %% [markdown]
# # 🏎️ CarRacing RL — Google Colab Notebook
# This notebook installs dependencies, clones your repo, and runs training/evaluation.

# %% [markdown]
# ## 🔧 Step 1 — Install Dependencies

# %%
# !apt-get update
# !apt-get install -y swig cmake build-essential
# !pip install gymnasium[box2d]
# !pip install pygame torch torchvision numpy pandas matplotlib opencv-python pyyaml
# !pip install pybox2d
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Hit:2 https://cli.github.com/packages stable InRelease
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:7 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [83.4 kB]
# Get:8 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,153 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:11 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,835 kB]
# Get:12 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,535 kB]
# ...

# %% [markdown]
# ## 📂 Step 2 — Clone Repo

# %%
# !git clone https://github.com/jackburke12/DS5004-Car-Racing.git
# %cd DS5004-Car-Racing
# Out:
# Cloning into 'DS5004-Car-Racing'...
# remote: Enumerating objects: 69, done.
# remote: Counting objects: 100% (69/69), done.
# remote: Compressing objects: 100% (48/48), done.
# remote: Total 69 (delta 34), reused 47 (delta 21), pack-reused 0 (from 0)
# Receiving objects: 100% (69/69), 158.38 KiB | 1.33 MiB/s, done.
# Resolving deltas: 100% (34/34), done.
# /content/DS5004-Car-Racing

# %% [markdown]
# Pull From repo if needed

# %%
# !git pull

# %% [markdown]
# ## ▶️ Step 3 — Run Training

# %%
# !python train.py --config configs/td3.yaml
# Out:
# ===== Training td3 =====
# Config: configs/td3.yaml
# Episodes: 800
# Output: checkpoints/td3
# ...
#
# Episode    1 | Reward:   -31.1 | Avg50:  -31.15 | Epsilon: 0.000
# Episode    2 | Reward:   -29.3 | Avg50:  -30.22 | Epsilon: 0.000
# Episode    3 | Reward:   -29.8 | Avg50:  -30.09 | Epsilon: 0.000
# Episode    4 | Reward:   -36.7 | Avg50:  -31.74 | Epsilon: 0.000
# Episode    5 | Reward:   -28.8 | Avg50:  -31.16 | Epsilon: 0.000
# Traceback (most recent call last):
#   File "/content/DS5004-Car-Racing/train.py", line 193, in <module>
#     train(args.config)
#   File "/content/DS5004-Car-Racing/train.py", line 148, in train
#     agent.update()
#   File "/content/DS5004-Car-Racing/agents/td3_agent.py", line 164, in update
#     next_states_t = torch.tensor(next_states, dtype=torch.float32, device=self.device)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt

# %%
# !python train.py --config configs/ddpg.yaml
# Out:
# ===== Training ddpg =====
# Config: configs/ddpg.yaml
# Episodes: 800
# Output: checkpoints/ddpg
# ...
#
# Episode    1 | Reward:   -31.1 | Avg50:  -31.15 | Epsilon: 0.000
# Episode    2 | Reward:   -29.3 | Avg50:  -30.22 | Epsilon: 0.000
# Episode    3 | Reward:   -29.8 | Avg50:  -30.09 | Epsilon: 0.000
# Episode    4 | Reward:   -36.7 | Avg50:  -31.74 | Epsilon: 0.000
# Episode    5 | Reward:   -28.8 | Avg50:  -31.16 | Epsilon: 0.000
# Episode    6 | Reward:   -81.0 | Avg50:  -39.47 | Epsilon: 0.000
# Episode    7 | Reward:   -78.1 | Avg50:  -44.99 | Epsilon: 0.000
# Episode    8 | Reward:   -76.0 | Avg50:  -48.86 | Epsilon: 0.000
# Episode    9 | Reward:   -81.8 | Avg50:  -52.52 | Epsilon: 0.000
# Episode   10 | Reward:   -83.8 | Avg50:  -55.64 | Epsilon: 0.000
# Episode   11 | Reward:   -82.0 | Avg50:  -58.04 | Epsilon: 0.000
# Episode   12 | Reward:   -80.5 | Avg50:  -59.91 | Epsilon: 0.000
# Episode   13 | Reward:   -78.9 | Avg50:  -61.37 | Epsilon: 0.000
# ...

# %%
# !python train.py --config configs/dqn.yaml
# Out:
# ===== Training dqn =====
# Config: configs/dqn.yaml
# Episodes: 1500
# Output: checkpoints/dqn
# ...
#
# Episode    1 | Reward:   -54.1 | Avg50:  -54.10 | Epsilon: 0.998
# Episode    2 | Reward:   -52.9 | Avg50:  -53.48 | Epsilon: 0.996
# Episode    3 | Reward:   -57.9 | Avg50:  -54.95 | Epsilon: 0.994
# Episode    4 | Reward:   -58.9 | Avg50:  -55.93 | Epsilon: 0.992
# Episode    5 | Reward:   -49.2 | Avg50:  -54.57 | Epsilon: 0.991
# Episode    6 | Reward:   -58.9 | Avg50:  -55.29 | Epsilon: 0.989
# Episode    7 | Reward:   -59.0 | Avg50:  -55.82 | Epsilon: 0.987
# Episode    8 | Reward:   -55.0 | Avg50:  -55.71 | Epsilon: 0.985
# Episode    9 | Reward:   -41.6 | Avg50:  -54.15 | Epsilon: 0.983
# Episode   10 | Reward:   -57.8 | Avg50:  -54.51 | Epsilon: 0.981
# Episode   11 | Reward:   -53.2 | Avg50:  -54.39 | Epsilon: 0.979
# Episode   12 | Reward:   -57.8 | Avg50:  -54.68 | Epsilon: 0.977
# Episode   13 | Reward:   -50.7 | Avg50:  -54.37 | Epsilon: 0.975
# ...

# %%
# !python train.py --config configs/double_dqn.yaml

# %%
# !python train.py --config configs/dueling_dqn.yaml

# %% [markdown]
# ## 🧪 Step 4 — Evaluate a Model

# %%
# !python evaluate.py --config configs/dqn.yaml --checkpoint checkpoints/dqn/dqn_ep1500.pth --no-render

# %% [markdown]
# ## 📈 Step 5 — Plot Results

# %%
# !python plot_results.py --files results/dqn_results.csv results/double_dqn_results.csv results/dueling_dqn_results.csv
